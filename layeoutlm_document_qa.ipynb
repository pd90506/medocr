# %%
from transformers import pipeline

nlp = pipeline(
    "document-question-answering",
    model="impira/layoutlm-document-qa",
)

nlp(
    "images/clinic_paper_1.jpg",
    "What's the value of LEUCOCITOS?"
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 8
#       1 from transformers import pipeline
#       3 nlp = pipeline(
#       4     "document-question-answering",
#       5     model="impira/layoutlm-document-qa",
#       6 )
# ----> 8 nlp(
#       9     "images/clinic_paper_1.jpg",
#      10     "What's the value of LEUCOCITOS?"
#      11 )
#
# File ~/.local/lib/python3.11/site-packages/transformers/pipelines/document_question_answering.py:271, in DocumentQuestionAnsweringPipeline.__call__(self, image, question, word_boxes, **kwargs)
#     269 else:
#     270     inputs = image
# --> 271 return super().__call__(inputs, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/transformers/pipelines/base.py:1188, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
# ...
